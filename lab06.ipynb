# %%
# from __future__ import print_function, division

# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit

# %% [markdown]
# # Part 1

# %%
def gaussian (x,mu,sig):
    return np.exp(-np.power(x-mu,2.)/(2*np.power(sig,2.)))

# %%
arrx = np.arange(-5,5,0.01)
arry = gaussian(arrx,0,2)
plt.plot(arrx, arry)
plt.plot (arrx,gaussian(arrx,1,1))
plt.plot (arrx,gaussian(arrx,-1,0.1))
plt.plot(arrx,gaussian(arrx,3,2))
plt.plot (arrx,gaussian(arrx,1,0.4))

# %%
arr, covarience = curve_fit(gaussian, arrx,arry, [0,2])
yfit = gaussian (arrx,*arr)
plt.plot(arrx,yfit)

# TODO plot result

# %%
lambda_units, signal = np.loadtxt('HDalpha_data', unpack = True)

# %%
plt.plot(lambda_units,signal)

# %%
arrsignal = gaussian(lambda_units,13127.5,0.5) + gaussian (lambda_units,13131.5,0.5)

# %%
plt.plot(lambda_units,1-arrsignal)
plt.plot(lambda_units,arrsignal)

# %% [markdown]
# # Part 2

# %%
r1 = []
r2 = []
for i in range (0,100):
    r1.append(np.random.uniform(0,1))
    r2.append(np.random.uniform(0,1))
r1 = np.array(r1)    
r2 = np.array(r2)


plt.figure(figsize=(20,20))
plt.suptitle("Random Scatter", size = 100)
plt.subplot(2,2,1).scatter(r1[0:25],r2[0:25], c = 'Red', alpha = 0.9,  s = 100*r2[0:25])
plt.title("0 - 25", size = 30, color = 'Red')
plt.xticks([])
plt.yticks([])
plt.subplot(2,2,2).scatter(r1[25:50],r2[25:50], c = 'Blue', alpha = 0.7,s = 100*r1[25:50])
plt.title("25 - 50", size = 30,  color = 'Blue')
plt.xticks([])
plt.yticks([])
plt.subplot(2,2,3).scatter(r1[50:75],r2[50:75], c = 'Green', alpha = 0.5, s = 100*r2[50:75])
plt.title("50 - 75", size = 30,  color = 'Green')
plt.xticks([])
plt.yticks([])
plt.subplot(2,2,4).scatter(r1[75:100],r2[75:100], c = 'Purple', alpha = 0.3, s = 100*r1[75:100])
plt.title("75 - 100", size = 30,  color = 'Purple')
plt.xticks([])
plt.yticks([])
plt.show()

plt.savefig('lab6_question2.pdf')

# %% [markdown]
# # Part 3

# %%
def flux_for_dipole(x_pos, y_pos, Q_vals, X, Y):
    """
    Returns the flux based on the information of the charges
    and the grid of the plot.
    Code modified from Physics 113, written by Blas Cabrera
    """
    flux = np.zeros((len(X), len(Y)))
    x_m = np.outer(np.ones((X.size)), X); 
    y_m = np.outer(Y, np.ones((Y.size))); 
    for n in range(len(Q_vals)):
        flux += 2*np.pi*Q_vals[n]*(1 - (x_pos[n]-x_m)/np.sqrt((y_pos[n]-y_m)**2+(x_pos[n]-x_m)**2))
    return flux

# %%
# TODO create arrays of information

# TODO get flux

# TODO plot contours of the flux
